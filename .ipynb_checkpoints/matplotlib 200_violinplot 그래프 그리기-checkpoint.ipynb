# %%
# %matplotlib inline

# %% [markdown]
# ## 파일을 깃허브에서 읽고 처리하기

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# Initialize Figure and Axes object
fig, ax = plt.subplots()

# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create violinplot
ax.violinplot(tips["total_bill"], vert=False)

# Show the plot
plt.show()

# %%
# !pip install seaborn updates
# Out:
# Requirement already satisfied: seaborn in /Users/dahlmoon/anaconda/lib/python3.6/site-packages
# Collecting updates
#   Downloading updates-0.1.7.1.tar.gz
# Building wheels for collected packages: updates
#   Running setup.py bdist_wheel for updates ... done
#   Stored in directory: /Users/dahlmoon/Library/Caches/pip/wheels/d6/e7/40/fd8bf7c04438f418d14456de3072bd1c61a43543939532304a
# Successfully built updates
# Installing collected packages: updates
# Successfully installed updates-0.1.7.1

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()
# Out:
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %% [markdown]
# ## 시본을 이용해서 그래프 그리기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load iris data
iris = sns.load_dataset("iris")

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()
