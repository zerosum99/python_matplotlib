# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # Marker 처리하기

# %% [markdown]
# ### circle  marker

# %%
# Make an array of x values
x = [1, 2, 3, 4, 5]
# Make an array of y values for each x value
y = [1, 4, 9, 16, 25]
# use pylab to plot x and y as red circles
plt.plot(x, y, 'ro')

# %% [markdown]
# ### square marker

# %%
plt.plot(x, y, 'rs')

# %% [markdown]
# ### pentagon marker

# %%
plt.plot(x, y, 'rp')

# %% [markdown]
# ###  star marker

# %%
plt.plot(x, y, 'r*')

# %% [markdown]
# ### hexagon1 marke

# %%
plt.plot(x, y, 'rh')

# %% [markdown]
# ### hexagon2 marker

# %%
plt.plot(x, y, 'rH')

# %% [markdown]
# ### plus marker

# %%
plt.plot(x, y, 'r+')

# %% [markdown]
# ### x marker

# %%
plt.plot(x, y, 'rx')

# %% [markdown]
# ### diamond marker

# %%
plt.plot(x, y, 'rd')

# %% [markdown]
# ### thin diamond marker

# %%
plt.plot(x, y, 'rD')

# %% [markdown]
# ### "8"	octagon

# %%
plt.plot(x, y, 'r8')

# %% [markdown]
# ### triangle_down

# %%
plt.plot(x, y, 'rv')

# %%
plt.plot(x, y, 'r1')

# %% [markdown]
# ### triangle_up

# %%
plt.plot(x, y, 'r^')

# %%
plt.plot(x, y, 'r2')

# %% [markdown]
# ###  triangle_left

# %%
plt.plot(x, y, 'r<')

# %%
plt.plot(x, y, 'r3')

# %% [markdown]
# ### triangle_right

# %%
plt.plot(x, y, 'r>')

# %%
plt.plot(x, y, 'r4')

# %% [markdown]
# ## 마커의 종류
#
#     Triangle-shaped: v, <, >, ^
#     Cross-like: *, +, 1, 2, 3, 4
#     Circle-like: o, ., h, p, H, 8

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

# Get colors / markers / functions
colors = ('b', 'g', 'r', 'c', 'm', 'y', 'k')
markers = []
for m in Line2D.markers:
    try:
        if len(m) == 1 and m != ' ':
            markers.append(m)
    except TypeError:
        pass

f1 = lambda xs: [x**2 for x in xs]
f2 = lambda xs: [x**3 for x in xs]
f3 = lambda xs: np.sin(xs)
f4 = lambda xs: np.log(xs)
f5 = lambda xs: [x**0.5 for x in xs]
f6 = lambda xs: [x for x in xs]
f7 = lambda xs: [x + 1 for x in xs]
functions = [f1, f2, f3, f4, f5, f6, f7]

# Define the plot
plt.ylim(-1.0, 1.0)
plt.title("Example for matplotlib markers", fontweight='bold', fontsize=20)
plt.xlabel(r"""x-axis label""", fontsize=20)
plt.ylabel(r"""y-axis label""", fontsize=20)

# Define at which x positions to evaluate the functions f_i(x)
xmin = -1
xmax = 1
samples = 50
xs = np.linspace(xmin, xmax, samples)

# Plot the functions
for color, marker, f in zip(colors, markers, functions):
    format_str = "{color}{marker}-".format(color=color, marker=marker)
    plt.plot(xs, f(xs), format_str, label=format_str)

plt.axhline(y=0.20)
plt.legend(fontsize=20)
plt.show() # or plt.show()
# Out:
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in log
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars

# %%
# Plot the functions
for color, marker, f in zip(colors, markers, functions):
    format_str = "{color}{marker}-".format(color=color, marker=marker)
    plt.plot(xs, f(xs), format_str, label=format_str)

plt.axhline(y=0.20)
plt.legend(fontsize=20)
plt.show() # or plt.show()
# Out:
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in log
# /Users/dahlmoon/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars
