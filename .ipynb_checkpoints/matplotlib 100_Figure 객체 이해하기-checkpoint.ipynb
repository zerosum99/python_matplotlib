# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# # figure 객체를 이해하기

# %% [markdown]
# ## 세개의 subplot을 만들기

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig

# %% [markdown]
# ## 그래프의 구조
#
#
#     모든 그림은 Figure 라고 하는 부르는 matplotlib.figure.Figure 클래스 객체에 포함되어 있다.
#     내부 플롯(inline plot)이 아닌 경우에는 하나의 Figure는 하나의 아이디 숫자와 윈도우(Window)를 가진다.

# %%
from IPython.display import Image
image = Image('figure.png')
image

# %%
f1 = plt.figure(figsize=(10, 2))
plt.plot(np.random.randn(100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3a705dce82bd> in <module>()
# ----> 1 f1 = plt.figure(figsize=(10, 2))
#       2 plt.plot(np.random.randn(100))
#       3 plt.show()
#
# NameError: name 'plt' is not defined
